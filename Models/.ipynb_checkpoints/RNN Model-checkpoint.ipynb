# %% [markdown]
# # <center>Generating Music Using LSTM Cells</center>

# %%
# Imports
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
from music21 import converter, instrument, note, chord, stream
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import Callback
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import CuDNNLSTM, LSTM, Bidirectional
from keras.layers import Activation
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, History

# %% [markdown]
# This function will get the notes from all midi files

# %%
def get_notes(path):
    """ Get all the notes and chords from the midi files """
    notes = []

    for file in glob.glob(path + "*.mid"):
        print("Parsing %s" % file)
        
        midi = converter.parse(file)
        
        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
            
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    return notes

# %%
def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    # get all pitch names
    pitchnames = sorted(set(item for item in notes))

     # create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])

    # reshape the input into a format compatible with LSTM layers
    n_patterns = len(network_input)
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input between 0 and 1
    network_input = network_input / float(n_vocab)

    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

# %%
def create_network(network_input, n_vocab):
    """ create the structure of the neural network """
    model = Sequential()
    model.add(CuDNNLSTM(512,input_shape=(network_input.shape[1], network_input.shape[2]),return_sequences=True))
    model.add(Dropout(0.3))
    model.add(Bidirectional(CuDNNLSTM(512, return_sequences=True)))
    model.add(Dropout(0.3))
    model.add(Bidirectional(CuDNNLSTM(512)))
    model.add(Dense(256))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
def generate_notes(model, notes, network_input, n_vocab):
    """ Generate notes from the neural network based on a sequence of notes """
    # pick a random sequence from the input as a starting point for the prediction
    pitchnames = sorted(set(item for item in notes))
    
    start = np.random.randint(0, len(network_input)-1)
    print(start)

    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

    pattern = network_input[start]
    prediction_output = []
    print(pattern)

    # generate 500 notes
    for note_index in range(500):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = np.argmax(prediction)
        result = int_to_note[index]
        prediction_output.append(result)
        
        pattern = np.append(pattern,index)
        pattern = pattern[1:len(pattern)]
    
    print(prediction_output)

    return prediction_output

# %%
def create_midi(prediction_output, filename):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)
        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='{}.mid'.format(filename))

# %%
""" Train a Neural Network to generate music """
# Get notes from midi files
filepaths = ["../Pokemon MIDIs/", "../LoZ MIDIs/"]
notes = get_notes(filepaths[1])

# Get the number of pitch names
n_vocab = len(set(notes))

# Convert notes into numerical input
network_input, network_output = prepare_sequences(notes, n_vocab)
# Out:
# Parsing ../LoZ MIDIs\Legend of Zelda - Link to the Past -- Ending Fanfare.mid
# Parsing ../LoZ MIDIs\Legend of Zelda - Overworld.mid
# Parsing ../LoZ MIDIs\Super Smash Bros Brawl - The Legend of Zelda Dark World.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Death Mountain.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Dungeon.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Ending.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Flute.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Game Over.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Ganon Appears and is Defeated.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Get Treasure Fanfare.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Get Triforce Fanfare.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Lost Woods Duet.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Overworld.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Title.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Uncover Secret.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda - Zelda is Rescued Fanfare.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda 25th Anniversary Concert CD - Gerudo Valley.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Beginning Field.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Hildas Theme.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Lorule Castle.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Ravios Theme.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Swamp Palace.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Thieves Hideout.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Witchs House.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link Between Worlds - Yuga Battle Eastern Palace.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Agahnim.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Being a Bunny.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Boss Battle.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Boss Victory Fanfare.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Cave.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Church.mid
# Parsing ../LoZ MIDIs\The Legend of Zelda A Link to the Past - Credits.mid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-d4f012933909> in <module>
#       2 # Get notes from midi files
#       3 filepaths = ["../Pokemon MIDIs/", "../LoZ MIDIs/"]
# ----> 4 notes = get_notes(filepaths[1])
#       5
#       6 # Get the number of pitch names
#
# <ipython-input-24-e0bca986089d> in get_notes(path)
#       6         print("Parsing %s" % file)
#       7
# ----> 8         midi = converter.parse(file)
#       9
#      10         notes_to_parse = None
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\converter\__init__.py in parse(value, *args, **keywords)
#    1127     elif not isinstance(value, bytes) and os.path.exists(valueStr):
#    1128         return parseFile(valueStr, number=number, format=m21Format,
# -> 1129                          forceSource=forceSource, **keywords)
#    1130     elif not isinstance(value, bytes) and os.path.exists(common.cleanpath(valueStr)):
#    1131         return parseFile(common.cleanpath(valueStr), number=number, format=m21Format,
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\converter\__init__.py in parseFile(fp, number, format, forceSource, **keywords)
#    1007     v = Converter()
#    1008     fp = common.cleanpath(fp, returnPathlib=True)
# -> 1009     v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1010     return v.stream
#    1011
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\converter\__init__.py in parseFile(self, fp, number, format, forceSource, storePickle, **keywords)
#     531             environLocal.printDebug('Loading Pickled version')
#     532             try:
# --> 533                 self._thawedStream = thaw(fpPickle, zipType='zlib')
#     534             except freezeThaw.FreezeThawException:
#     535                 environLocal.warn('Could not parse pickle, %s ...rewriting' % fpPickle)
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\converter\__init__.py in thaw(fp, zipType)
#    1200     from music21 import freezeThaw
#    1201     v = freezeThaw.StreamThawer()
# -> 1202     v.open(fp, zipType=zipType)
#    1203     return v.stream
#    1204
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\freezeThaw.py in open(self, fp, zipType)
#     949                 uncompressed = zlib.decompress(compressedString)
#     950                 try:
# --> 951                     storage = pickle.loads(uncompressed)
#     952                 except AttributeError as e:
#     953                     raise FreezeThawException('Problem in decoding: {}'.format(e))
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\music21\duration.py in __setstate__(self, state)
#    1578
#    1579     def __setstate__(self, state):
# -> 1580         SlottedObjectMixin.__setstate__(self, state)
#    1581         self._client = common.wrapWeakref(self._client)
#    1582
#
# KeyboardInterrupt:

# %%
# Set up the model
model = create_network(network_input, n_vocab)
history = History()

# Save on each epoch (because training isn't cheap!!!)
outputDest = '../output/LSTM_LoZ_' + str(int(time.time())) + '/'
if not os.path.exists(outputDest):
    os.makedirs(outputDest)
    
class CustomSaver(Callback):
    def on_epoch_end(self, epoch, logs={}):
        self.model.save(outputDest + "LSTMmodel_{}.hd5".format(epoch))
        
saver = CustomSaver()

# Fit the model
n_epochs = 2
model.summary()
model.fit(network_input, network_output, callbacks=[history, saver], epochs=n_epochs, batch_size=64)
model.save(outputDest + 'LSTMmodel_final.h5')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_13 (CuDNNLSTM)    (None, 100, 512)          1054720
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100, 512)          0
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 100, 1024)         4202496
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 100, 1024)         0
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 1024)              6299648
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               131584
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# =================================================================
# Total params: 11,950,848
# Trainable params: 11,950,848
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2
#   5056/196343 [..............................] - ETA: 11:47 - loss: 5.0545
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-3c4eaccaae33> in <module>
#      17 n_epochs = 2
#      18 model.summary()
# ---> 19 model.fit(network_input, network_output, callbacks=[history, saver], epochs=n_epochs, batch_size=64)
#      20 model.save(outputDest + 'LSTMmodel_final.h5')
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~\Anaconda3\envs\CITS4404\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Use the model to generate a midi
prediction_output = generate_notes(model, notes, network_input, len(set(notes)))
create_midi(prediction_output, outputDest + 'LSTM_output')

# Plot the model losses
pd.DataFrame(history.history).plot()
plt.savefig(outputDest + 'LSTM_Loss_per_Epoch.png', transparent=True)
plt.close()
# Out:
# 44016
# [[0.83984375]
#  [0.85742188]
#  [0.8828125 ]
#  [0.8671875 ]
#  [0.84375   ]
#  [0.3359375 ]
#  [0.82226562]
#  [0.83984375]
#  [0.82226562]
#  [0.83984375]
#  [0.82226562]
#  [0.83984375]
#  [0.82226562]
#  [0.83984375]
#  [0.14257812]
#  [0.82226562]
#  [0.83984375]
#  [0.82226562]
#  [0.83984375]
#  [0.82226562]
#  [0.83984375]
#  [0.8828125 ]
#  [0.8671875 ]
#  [0.82617188]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.97460938]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.95898438]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.41601562]
#  [0.95898438]
#  [0.95507812]
#  [0.98828125]
#  [0.97070312]
#  [0.26367188]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.82617188]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.97460938]
#  [0.92382812]
#  [0.95507812]
#  [0.98828125]
#  [0.97070312]
#  [0.85742188]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.26171875]
#  [0.85742188]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.22070312]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.98828125]
#  [0.97070312]
#  [0.82617188]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.97460938]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.95898438]
#  [0.92382812]
#  [0.95507812]
#  [0.92382812]
#  [0.95507812]
#  [0.41601562]
#  [0.95898438]
#  [0.95507812]
#  [0.98828125]]
# ['11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4']
